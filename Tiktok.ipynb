# %%
# Dependencies and Setup
import pandas as pd
from pathlib import Path

# File to Load 
Tiktok_2019 = Path("Resources/Tiktok_songs_2019.csv")
Tiktok_2020 = Path("Resources/Tiktok_songs_2020.csv")
Tiktok_2021 = Path("Resources/Tiktok_songs_2021.csv")
Tiktok_2021_other = Path("Resources/Tiktok_songs_2021_otherone.csv")
Tiktok_2022 = Path("Resources/Tiktok_songs_2022.csv")


# Read csv files and store into Pandas DataFrames
data_2019 = pd.read_csv(Tiktok_2019)
data_2020 = pd.read_csv(Tiktok_2020)
data_2021 = pd.read_csv(Tiktok_2021)
data_other_2021 = pd.read_csv(Tiktok_2021_other)
data_2022 = pd.read_csv(Tiktok_2022)

# %%
data_2022
# Out:
#                                  track_name      artist_name  artist_pop  \
# 0    Running Up That Hill (A Deal With God)        Kate Bush          81
# 1                                 As It Was     Harry Styles          91
# 2                                   Sunroof      Nicky Youre          73
# 3                                Heat Waves    Glass Animals          80
# 4                           About Damn Time            Lizzo          81
# ..                                      ...              ...         ...
# 258              The Less I Know The Better      Tame Impala          78
# 259                              Dandelions          Ruth B.          75
# 260           Jimmy Cooks (feat. 21 Savage)            Drake          95
# 261                            Good Looking  Suki Waterhouse          64
# 262                                 INFERNO        Sub Urban          67
#
#                           album  track_pop  danceability  energy  loudness  \
# ...

# %%
data_2021
# Out:
#                           TikTok_songs_2021     Unnamed: 1  Unnamed: 2  \
# 0                                track_name    artist_name  artist_pop
# 1                 STAY (with Justin Bieber)  The Kid LAROI          83
# 2    Peaches (feat. Daniel Caesar & Giveon)  Justin Bieber          90
# 3                edamame (feat. Rich Brian)          bbno$          72
# 4                       Here's Your Perfect   Jamie Miller          65
# ..                                      ...            ...         ...
# 186                                   Panda      Desiigner          63
# 187                             TO THE MOON       Jnr Choi          63
# 188                             Upside Down           JVKE          71
# 189                                  lowkey           NIKI          75
# 190               Desce Pro Play (PA PA PA)           ZAAC          60
#
#                      Unnamed: 3 Unnamed: 4    Unnamed: 5 Unnamed: 6  \
# ...

# %%
data_2020
# Out:
#                     TikTok_songs_2020                Unnamed: 1  Unnamed: 2  \
# 0                          track_name               artist_name  artist_pop
# 1                              Say So                  Doja Cat          88
# 2                     Blinding Lights                The Weeknd          93
# 3    Supalonely (feat. Gus Dapperton)                     BENEE          67
# 4                              Savage       Megan Thee Stallion          82
# ..                                ...                       ...         ...
# 288                           Buttons        The Pussycat Dolls          68
# 289                          Get Busy                 Sean Paul          79
# 290      ROCKSTAR (feat. Roddy Ricch)                    DaBaby          82
# 291                          Who Says  Selena Gomez & The Scene          67
# 292                   Crystal Dolphin                 Engelwood          50
#
# ...

# %%
data_other_2021
# Out:
#                            TikTok_songs_2021_otherone              Unnamed: 1  \
# 0                                          track_name             artist_name
# 1                                             abcdefu                   GAYLE
# 2                               Smokin Out The Window              Bruno Mars
# 3                                             As I Am                  H.E.R.
# 4                                          I AM WOMAN               Emmy Meli
# 5   SAD GIRLZ LUV MONEY Remix (feat. Kali Uchis an...                 Amaarae
# 6                              Yucky Blucky Fruitcake                 Doechii
# 7                              I Am (feat. Flo Milli)               Baby Tate
# 8                                        Cold Blooded                   Jessi
# 9                                              energy               Tyla Jane
# 10                               lovely (with Khalid)           Billie Eilish
# ...

# %%
# removing extraneous head rows
df_2019 = data_2019
df_2019.head()
df_2019["Year"] = 2019
# Out:
#                 track_name                 artist_name  artist_pop  \
# 0                 Shake It               Metro Station          53
# 1         Chinese New Year                       SALES          61
# 2           Baby I'm Yours                    Breakbot          57
# 3               The Git Up                Blanco Brown          60
# 4     Say Hey (I Love You)  Michael Franti & Spearhead          58
# ..                     ...                         ...         ...
# 218   Skinny Legend Anthem                  Ava Louise          32
# 219          Material Girl                     Madonna          77
# 220    I Wish - Radio Edit                     Skee-Lo          51
# 221  Oh No I Got a Disease                   Buss Crew          11
# 222                  Woahh                        Jufu          31
#
#                                  album  track_pop  danceability  energy  \
# 0                        Metro Station         68         0.618   0.955
# ...
