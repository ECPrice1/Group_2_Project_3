# %%
# Dependencies and Setup
import pandas as pd
from pathlib import Path

# File to Load 
Tiktok_2019 = Path("Resources/Tiktok_songs_2019.csv")
Tiktok_2020 = Path("Resources/Tiktok_songs_2020.csv")
Tiktok_2021 = Path("Resources/Tiktok_songs_2021.csv")
Tiktok_2021_other = Path("Resources/Tiktok_songs_2021_otherone.csv")
Tiktok_2022 = Path("Resources/Tiktok_songs_2022.csv")


# Read csv files and store into Pandas DataFrames
data_2019 = pd.read_csv(Tiktok_2019)
data_2020 = pd.read_csv(Tiktok_2020)
data_2021 = pd.read_csv(Tiktok_2021)
data_other_2021 = pd.read_csv(Tiktok_2021_other)
data_2022 = pd.read_csv(Tiktok_2022)

# %%
# removing extraneous head rows
df_2019 = data_2019.iloc[1:]
df_2019.head()
# Out:
#                                                                                                                                                                                           TikTok_songs_2019
# track_name       artist_name   artist_pop album         track_pop danceability energy loudness mode key speechiness acousticness instrumentalness liveness valence tempo   time_signature       duration_ms
# Shake It         Metro Station 53         Metro Station 68        0.618        0.955  -3.836   1    4   0.0798      0.00221      3.09E-06         0.486    0.79    150.034 4                         179947
# Chinese New Year SALES         61         SALES - EP    53        0.744        0.845  -7.422   0    4   0.253       0.759        0.232            0.1      0.749   75.221  4                         160000
# Baby I'm Yours   Breakbot      57         By Your Side  69        0.829        0.792  -3.755   0    2   0.0668      0.726        5.83E-06         0.122    0.758   118.05  4                         215507
# The Git Up       Blanco Brown  60         The Git Up    2         0.847        0.678  -8.635   1    9   0.109       0.0669       0                0.274    0.811   97.984  4                         200594
